# %%
from utils import parse_iob_file_to_dataframe

train_df = parse_iob_file_to_dataframe("../data/train.iob")
test_df = parse_iob_file_to_dataframe("../data/test.iob")

# %%
test_df
# Out:
#                                                    hash  \
# 0     06005a1e39f158840d68b43dd767b3e03e0f0b62837583...
# 1     14a3cee520d11383f027f1b004994f79a1f79e9f2d8578...
# 2     c4714c4e85fe3597c5cc78bb51f6736ce5ce5a334ed1dd...
# 3     54594a73848e56c48f98bf9cd781b4eada346b03e87fc4...
# 4     8ee875c6a6ebfa66865e4d10b9779f52ecf0111a00c6ec...
# ...                                                 ...
# 5082  870d31a802556defa0b40964879d00cd95432bfac550ef...
# 5083  23bdf62e598bab6563ce9fa3986f13ff9fc55e2d1fcb87...
# 5084  5b13f6dfe178112faf0dd393903abbef9b6d3c540efed0...
# 5085  df441302abdae8666df766d31bcf5603931aa48a27d5f2...
# 5086  0397accb0b36e8e300b7c8acfa465a755d254af557cb97...
#
#                                                    text  \
# 0     Вивчали хімічний режим підземних вод , які вик...
# 1     За органолептичними показниками та хімічним ск...
# 2     Проте у воді досліджуваних господарств виявили...
# 3      Вода - важлива складова всього живого на Землі .
# ...

# %%
train_df
# Out:
#                                                     hash  \
# 0      fe48a1e94b6a92e8062ba4b41fc5c5421a717ae8622758...
# 1      7858fde68061252183080d8ac78fa4555cb2ab0b03b639...
# 2      dcf37203b22d51299f2dc7a08f53dce839b6d744b44e60...
# 3      45bd27e836b62945cd8e19096a252f2d5220f2e142072d...
# 4      505cc7efd0e374de9f832e6779b760c2d596b1a2b016e2...
# ...                                                  ...
# 11156  d304b1cd96f5b9a06f3ae13228a1ed1b4916eba427324e...
# 11157  3971f7ce99207e1ca3a6bb6bc70e54e4e780eb907c68f5...
# 11158  6771e350393b6c48986504ce4eb87b0f9c19daff47c2d5...
# 11159  85b11c9e3e3ea108add834a4791dcd017489e7a5a27d3d...
# 11160  b694bfe68515e94e5f6212b7de428659e05eb8eab68de1...
#
#                                                     text  \
# 0      Дорогою зупинялися в селах , старцювали . Усти...
# 1      То молитви продавав свої спудейські , то щось ...
# 2      Дуже часто дід досить точно вказував , куди са...
# ...

# %%
train_df.to_csv("train.csv", index=False)

# %%
test_df.to_csv("test.csv", index=False)
